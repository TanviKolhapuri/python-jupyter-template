# %% [markdown]
# ### Exercise 3: Scatter Plot with Annotations

# %%
# TASK: Create a scatter plot with x = [1, 2, 3, 4, 5] and y = [2, 4, 6, 8, 10].
# Annotate each point with its (x, y) value, and set the title as 'Scatter Plot with Annotations'.

import matplotlib.pyplot as plt

# Data
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]

# Validate data
if not x:
    print("Error: The 'x' list is empty.")
elif not y:
    print("Error: The 'y' list is empty.")
elif len(x) != len(y):
    print("Error: The 'x' and 'y' lists must have the same length.")
else:
    # Create a scatter plot
    plt.scatter(x, y, color='r')

    # Annotate each point with (x, y) value
    for i in range(len(x)):
        plt.annotate(f'({x[i]}, {y[i]})', (x[i], y[i]), textcoords="offset points", xytext=(5,5), ha='center')

    # Customize plot
    plt.title('Scatter Plot with Annotations')
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.grid(True)

    # Show plot
    plt.show()
